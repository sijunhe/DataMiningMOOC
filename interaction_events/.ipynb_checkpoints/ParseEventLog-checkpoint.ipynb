# %%
#######################################################################################################################
## Parse Event Log 
## Written by: Sijun He
## Last Modified by: Sijun He
#######################################################################################################################
## The code extracts interaction events out of the log and store it in a dict for further development
## 1. Dictionary video_names:  
##      keys: the names of each video in the course
##      values: dictionarys (video) of data for each video
## 2. Dictionary video:  
##      keys: the names of users that watched the video
##      values: dictionarys (user) of data for each user
## 3. Dictionary user:  
##      keys: the four types of different events: 'play_video','stop_video','pause_video','seek_video'
##      values: a list of datas, for 'seek_video', the data is a tuple of ((old_time, new_time)
##                               for others, the data is just video_current_time
#######################################################################################################################
import csv, re
import numpy as np
event_type = ['play_video','stop_video','pause_video','seek_video']
video_names = {}
## need to change the file name to STDIN afterwards
with open('../../data/EarthSciences_ResGeo202_Spring2015_VideoInteraction.csv','r') as csvfile :
    lines = csv.reader(csvfile, delimiter = ',', quotechar = '"')
    for line in lines :
        if line[0] in event_type and line[1] != '':
            if line[1] not in video_names:
                video_names[line[1]] = {}
                
            video = video_names[line[1]]
            
            # use user names as keys to store events of each users
            if line[13] not in video:
                video[line[13]] = {}
            user = video[line[13]]
            
            # separates events since different events has differnet data
            
            
            ## 1. seek_video contains  "'video_old_time'", "'video_new_time'
            ##    store each seek events as a tuple of (old_time, new_time)
            if line[0] == 'seek_video':
                if 'seek_video' not in user:
                    user['seek_video'] = [(line[6], line[7])]
                else:
                    user['seek_video'].append((line[6], line[7]))
            
            ## 2. play_video & pause_video & stop_video contains video_current_time
            else:
                if line[0] not in user:
                    user[line[0]] = [line[2]]
                else:
                    user[line[0]].append(line[2])

# %%
## video_names dictionary
print video_names['']
# Out:
# {'5904a908d4bb9a0c0042c01c7f64f499bb4687ae': {'play_video': ['383', '383.905217', '0', '0'], 'pause_video': ['383.905217', '7.406656', '383.963951'], 'stop_video': ['383.905217', '383.963951']}, 'de2f7ea08233b5fa38932f1f3d37f8c8e0415e84': {'play_video': ['0', '0.138666', '0.490666', '0.586666', '0.768', '1.045333', '1.546666', '1.589333', '2.005333', '2.357333', '2.570666', '3.36', '3.936', '4.544', '5.173333', '6.346666', '6.741333', '7.136', '7.744', '8.170666', '8.330666', '8.736', '9.162666', '9.749333', '10.144', '10.549333', '11.146666', '11.946666', '12.96', '13.621333', '14.144', '14.56', '14.762666', '15.552', '15.946666', '16.352', '16.565333', '16.768', '17.770666', '18.133333', '19.562666', '20.16', '20.981333', '21.802666', '22.165333', '23.712', '24.490666', '25.194666', '25.728', '26.101333', '26.730666', '27.114666', '27.733333', '28.106666', '28.725333', '29.12', '29.472', '29.92', '30.698666', '30.912', '31.114666', '31.925333', '32.128', '33.002666', '33.162666', '33.802666', '33.962666', '34.165333', '34.602666', '34.784', '35.776', '36.192', '36.394666', '36.778666', '36.981333', '38.176', '38.368', '38.965333', '39.392', '39.477333', '40.192', '40.981333', '41.365333', '42.165333', '42.592', '43.178666', '43.584', '44.181333', '44.661333', '45.578666', '46.176', '46.592', '47.050666', '47.381333', '48.181333', '48.629333', '48.981333', '49.386666', '49.76', '50.186666', '50.570666', '51.573333', '52.192', '52.576', '