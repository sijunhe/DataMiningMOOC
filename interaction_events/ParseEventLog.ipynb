# %%
#######################################################################################################################
## Parse Event Log 
## Written by: Sijun He
## Last Modified by: Sijun He
#######################################################################################################################
## The code extracts interaction events out of the log and store it in a dict for further development
## 1. Dictionary video_names:  
##      keys: the names of each video in the course
##      values: dictionarys (video) of data for each video
## 2. Dictionary video:  
##      keys: the names of users that watched the video
##      values: dictionarys (user) of data for each user
## 3. Dictionary user:  
##      keys: the four types of different events: 'play_video','stop_video','pause_video','seek_video'
##      values: a list of datas, for 'seek_video', the data is a tuple of ((old_time, new_time)
##                               for others, the data is just video_current_time
#######################################################################################################################
import csv, re
import numpy as np
event_type = ['play_video','stop_video','pause_video','seek_video']
video_names = {}
video_name_id_matching = {}
## need to change the file name to STDIN afterwards
with open('../../data/EarthSciences_ResGeo202_Spring2015_VideoInteraction.csv','r') as csvfile :
    lines = csv.reader(csvfile, delimiter = ',', quotechar = '"')
    for line in lines :
        if line[0] in event_type and line[1] != '':
            if line[1] not in video_names:
                video_names[line[1]] = {}
                video_name_id_matching[line[14]] = line[1]
                
            video = video_names[line[1]]
            
            # use user names as keys to store events of each users
            if line[13] not in video:
                video[line[13]] = {}
            user = video[line[13]]
            
            # separates events since different events has differnet data
            
            
            ## 1. seek_video contains  "'video_old_time'", "'video_new_time'
            ##    store each seek events as a tuple of (old_time, new_time)
            if line[0] == 'seek_video':
                if 'seek_video' not in user:
                    user['seek_video'] = [(line[6], line[7])]
                else:
                    user['seek_video'].append((line[6], line[7]))
            
            ## 2. play_video & pause_video & stop_video contains video_current_time
            else:
                if line[0] not in user:
                    user[line[0]] = [line[2]]
                else:
                    if line[2] not in user[line[0]]:
                        user[line[0]].append(line[2])

# %%
## video_names dictionary
print video_names['Welcome Video']['ac138fe7146905b6349ac75b4d660c229ab7640a']['seek_video']
print video_names['Welcome Video']['ac138fe7146905b6349ac75b4d660c229ab7640a']['play_video']
print video_names['Welcome Video']['ac138fe7146905b6349ac75b4d660c229ab7640a']['pause_video']
print video_names['Welcome Video']['ac138fe7146905b6349ac75b4d660c229ab7640a']['stop_video']
# Out:
# [('31', '7.45076')]
# ['0', '34.549328', '277.814794', '288.936698', '289.192654', '278.650678', '368', '7.706169', '369.158411']
# ['34.549328', '278.650678', '277.814794', '289.192654', '368.902938', '288.936698', '369.158411', '33.063952']
# ['368.902938', '369.158411']

# %%
video_name_id_matching['i4x-EarthSciences-ResGeo202-video-1ef94a59c89e4a03a529b46b002b889f']
# Out:
# 'Unit 1.2 - Overview of Units 2, 3'

# %%
video= 'Unit 5.6 - Rock Tensile Strength'
user = '000fbf151167672b762925e2bb19b3e1e4c9ba45'
print (video_names[video][user]['pause_video']) 
print (video_names[video][user]['play_video']) 
print (video_names[video][user]['seek_video']) 
print (video_names[video][user]['stop_video'])
# Out:
668.44', '679.007809'), ('664.35', '670.81804'), ('680.3', '692.957287'), ('658.48', '670.30139'), ('658.48', '673.395734'), ('653.43', '668.585368'), ('668.44', '674.553346'), ('668.44', '671.74046'), ('693.53', '706.820934'), ('693.53', '697.598412'), ('701.25', '718.706426'), ('695.89', '705.338765'), ('688', '696.362991'), ('695.89', '710.723246'), ('724.6', '750.156266'), ('763.81', '777.006723'), ('756.56', '769.915618'), ('751.61', '757.6206'), ('724.6', '753.502547'), ('695.89', '728.081782'), ('649.85', '702.76357'), ('609.46', '654.142398'), ('609.46', '610.115292'), ('680.3', '686.665174'), ('688', '704.911128'), ('693.53', '708.728704'), ('724.6', '731.462962'), ('756.56', '765.338119'), ('763.81', '777.267372'), ('828.81', '843.96899'), ('820.78', '831.481166'), ('817.75', '842.31932'), ('875.97', '884.374502'), ('861.35', '879.249128'), ('887.78', '921.350916'), ('1007.27', '1024.275269'), ('1035.19', '1047.026449'), ('1065.18', '1074.712195'), ('1071.42', '1081.069259'), ('1112.98', '1119.400336'), ('101', '3.320813'), ('224', '102.240943'), ('415', '228.654063'), ('618', '419.418724'), ('859', '620.424869'), ('1068', '861.788492'), ('24', '1070'), ('321.78', '333.628027'), ('321.78', '333.932261'), ('321.78', '335.47981'), ('326.84', '335.277156'), ('332.06', '350.533852'), ('326.84', '353.396665'), ('337.15', '352.197747'), ('373.81', '389.983364'), ('387.39', '396.233934'), ('354.62', '391.298422'), ('366.78', '374.376118'), ('366.78', '393.363359'), ('401.75', '416.177933'), ('417.64', '431.276175'), ('428.27', '433.557359'), ('547.37', '563.060907'), ('563.21', '585.334963'), ('547.37', '564.653597'), ('588.13', '600.363354'), ('592.54', '619.0554'), ('597.35', '606.175817'), ('588.13', '663.363371'), ('658.48', '670.589405'), ('649.85', '658.48'), ('724.6', '729.823212'), ('724.6', '731.942874'), ('732.77', '747.790884'), ('732.77', '746.30982'), ('728.41', '758.682379'), ('724.6', '734.108644'), ('722.42', '726.289894'), ('903.58', '910.481914'), ('920.67', '945.150067'), ('924.46', '940.588088'), ('968.14', '983.063004'), ('980.54', '991.001904'), ('1021.11', '1027.006766'), ('1032.9', '1042.819976'), ('1021.11', '1033.576624'), ('1035.19', '1043.481267'), ('1040.78', '1046.895268'), ('1032.9', '1041.658299'), ('1029.2', '1064.113381'), ('1025.56', '1032.479128'), ('1040.78', '1045.702074'), ('1032.9', '1040.78'), ('1058.57', '1079.530436'), ('136.78', '143.633031'), ('125.69', '140.325778'), ('155.24', '180.261922'), ('146.25', '159.105758'), ('248.68', '257.15974'), ('599.63', '605.620816'), ('599.63', '611.174298'), ('599.63', '606.140925'), ('646.51', '653.455302'), ('635.038', '656.060736'), ('636.94', '653.142868'), ('1040.78', '1159.936398'), ('1029.2', '1040.78'), ('1122.84', '1131.714618'), ('6', '1070'), ('0', '14.265502')]
# ['1159.936398', '1160.005009']

# %%
a = {
}

# %%
a[(1,2)] = 1
a[(2,3)] = 2

# %%
a.keys()
# Out:
# [(1, 2), (2, 3)]
